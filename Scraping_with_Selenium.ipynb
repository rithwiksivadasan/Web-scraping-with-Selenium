# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import difflib 
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
import instaloader

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)
driver.get("https://opendorse.com/")
# Out:
# /var/folders/sf/72qw163j6sv68zg_2cx67t_h0000gn/T/ipykernel_35144/2169843597.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)
# /var/folders/sf/72qw163j6sv68zg_2cx67t_h0000gn/T/ipykernel_35144/2169843597.py:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)

# %%
# number of pages of data to be scraped 
n= 30
for i in range(1,n):
    driver.implicitly_wait(1)
    button=driver.find_element(By.CLASS_NAME,"sc-ab9b38c8-0.sc-e66bd5d1-0.hGzWTo.ikgnFL")
    #driver.implicitly_wait(1)
    button.click()

# %%
page_source = driver.page_source

# %%
list2
# Out:
# ['<a data-qa="link_marketplace-link-row_team-wisconsin-badgers" href="/wisconsin-badgers"><div class="sc-f98ffb9d-0 hPLtof"><div class="sc-f98ffb9d-11 ijmSDP"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;padding-top:100%"></span><img alt="Team - Wisconsin Badgers icon" data-nimg="responsive" decoding="async" src="https://marketplaces.opendorse.com/static/wisconsin-badgers/chip-logo.svg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></span></div><p class="sc-f2b7fe29-0 cHHzzk">Wisconsin Badgers</p></div>',
# ...

# %%
soup = BeautifulSoup(page_source, "html.parser")

# %%
spd

# %%
first_name=[]
last_name=[]
instagram_reach=[] 
twitter_reach=[] 
current_team=[] 
profile_link=[]
instagram_handle=[] 
twitter_handle=[] # fething \\\r
biography=[] 
athlete_type=[] #empty
sport=[] #empty
keys=[]

for p in range(0,32*(n+1)):
    if 'profile' in list2[p]:
        if 'href' in list2[p]:
            sample_list=[]    

            key= str(re.findall('(?<=href=\").*?(?=\")',list2[p]))
                 #print(key)
            special_characters=[']','[',"'",'\n']
            for i in special_characters:
                key=key.replace(i,"")
            keys.append(key)


         #profile_link.append(key)

            link='https://opendorse.com' + key

            profile_link.append(link)

            ath_page=BeautifulSoup(requests.get(link).content, "html.parser")



            sample_list=[]
            row = ath_page.find_all(('script'), attrs = {'type':'application/json'})

            line=row[0]
            st=str(line)

            list1 =st.split('}')

            for i in range(0,len(list1)):
                if 'firstName' in list1[i]:
                    sample_list=[]
                    #print(re.findall('(?<=\"firstName\":\").*?(?=\")',list1[i]))
                    key= str(re.findall('(?<=\"firstName\":\").*?(?=\")',list1[i]))
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")

                    first_name.append(key)
                    
            
            for i in range(0,len(list1)):
                if 'lastName' in list1[i]:
                    sample_list=[]
                    key= str(re.findall('(?<=\"lastName\":\").*?(?=\")',list1[i]))
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    last_name.append(key)
            
            
            for i in range(0,len(list1)):
                if 'currentTeams' in list1[i]:
                    key= str(re.findall('(?<=\"currentTeams\":\[\").*?(?=\")',list1[i]))
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    current_team.append(key)
                   
      
                                    


                 
            for i in range(0,len(list1)):
                if 'twitterUrl' in list1[i]:
                    sample_list=[]
                    key= str(re.findall('(?<="twitterUrl\":\").*?(?=\")',list1[i]))
                    #print(key)
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    
                    twitter_handle.append(key)                         

            for i in range(0,len(list1)):
                if 'biography' in list1[i]:
                    sample_list=[]
                    key= str(re.findall('(?<="biography\":\").*?(?=\")',list1[i]))
                    #print(key)
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    
                    biography.append(key)                         

            
            
            for i in range(0,len(list1)):
                if 'instagramUrl' in list1[i]:
                    sample_list=[]
                    key= str(re.findall('(?<="instagramUrl\":\").*?(?=\")',list1[i]))
                    #print(key)
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    
                    instagram_handle.append(key)     
                    
           
        
        
            for i in range(0,len(list1)):
                 if 'twitterReach' in list1[i]:
                    sample_list=[]
                    key= str(re.findall('(?<=\"twitterReach\":).*?(?=\,)',list1[i]))
                    #print(key)
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    if 'null' not in key:
                        key=int(key)
                    else:
                        key='No Account'
                    twitter_reach.append(key)          



            for i in range(0,len(list1)):
                 if 'accountIdentifier' in list1[i]:
                     sample_list=[]

                     key= str(re.findall('(?<=\"accountIdentifier\":).*?(?=\,)',list1[i]))
                     #print(key)
                     special_characters=[']','[',"'"]
                     for i in special_characters:
                         key=key.replace(i,"")
        

                     athlete_type.append(key)


            
            
            for i in range(0,len(list1)):
                 if 'sports' in list1[i]:
                     sample_list=[]

                     key= str(re.findall('(?<=\"sports\":).*?(?=\,)',list1[i]))
                     #print(key)
                     special_characters=[']','[',"'"]
                     for i in special_characters:
                         key=key.replace(i,"")
        

                     sport.append(key)
            
            
            
            
            
            for i in range(0,len(list1)):
                if 'instagramReach' in list1[i]:
                    sample_list=[]
                    key= str(re.findall('(?<=\"instagramReach\":).*?(?=\,)',list1[i]))
                    #print(key)
                    special_characters=[']','[',"'"]
                    for i in special_characters:
                        key=key.replace(i,"")
                    
#                     if key=='0':
#                         try:
#                             strValue = instagram_handle[-1]
#                             ch = '/'
#                             # Remove all characters before the character '/' from string
#                             listOfWords = strValue.split(ch, 1)
#                             if len(listOfWords) > 0: 
#                                 strValue = listOfWords[1]

#                             bot = instaloader.Instaloader()
#                             profile = instaloader.Profile.from_username(bot.context, strValue)
#                             key = profile.followers
#                         except:
#                             key='No Account'

                    
                    if 'null' not in key:
                        key=int(key)
                    else:
                        key='No Account'

                    instagram_reach.append(key) 

ath = {'first_name':first_name,'last_name':last_name,'current_team':current_team,'InstagramReach':instagram_reach,'twitterReach':twitter_reach,'instagramHandle':instagram_handle,'twitterHandle':twitter_handle,'biography':biography,'profileLink':profile_link,'Athlete_type':athlete_type,"Sport":sport}
df= pd.DataFrame(ath)

df['full_name']=df['first_name']+" " +df['last_name'] 
df=df[df["Sport"].str.contains("Basketball")]
df=df[df["Athlete_type"].str.contains("StudentAthlete")]


df.to_csv('scrapped_Jan4.csv', index=False)

# %%
instagram_reach
# Out:
# [47122,
#  12502,
#  507990,
#  32251,
#  0,
#  17171,
#  0,
#  6564,
#  8739,
#  1189,
#  13836,
#  10624,
#  2284,
#  1531,
#  42042,
#  'No Account',
#  45176,
#  9628,
#  19604,
#  30801,
#  7527,
#  4752,
#  12432,
#  0,
#  14125,
#  15538,
#  33535,
#  7192,
#  45908,
#  6711,
#  18125,
#  2404,
#  1354,
#  5724,
#  4159,
#  36646,
#  5918,
#  22846,
#  6241,
#  0,
#  40931,
#  8378,
#  0,
#  7067,
#  0,
#  0,
#  1190,
#  5196,
#  0,
#  'No Account',
#  5068,
#  0,
#  0,
#  5050,
#  0,
#  0,
#  12810,
#  32447,
#  'No Account',
#  0,
#  1825,
#  0,
#  7521,
#  0,
#  0,
#  1338,
#  0,
#  0,
#  4692,
#  6619,
#  3580,
#  'No Account',
#  8548,
#  2977,
#  0,
#  9516,
#  8932,
#  7370,
#  3793,
#  6404,
#  8734,
#  1802,
#  0,
#  15467,
#  3302,
#  2960,
#  0,
#  22186,
#  16405,
#  3082,
#  0,
#  3796,
#  19220,
#  11966,
#  16413,
#  0,
#  0,
#  5142,
#  11239,
#  12383,
#  4477,
#  0,
#  0,
#  'No Account',
#  1162,
#  21691,
#  1394,
#  2050,
#  2541,
#  2125,
#  0,
#  1820,
# ...
